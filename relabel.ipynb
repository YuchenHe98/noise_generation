# %%
import sqlite3
from sqlite3 import Error

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None

def is_gratitude(text):
    return False

# %%
database = input("please input the database name: ")
limit_message = input("please input the limit message: ")


user_table = {}

conn = create_connection(database)
with conn:
    cur = conn.cursor() 
    cur.execute("SELECT id, user_title FROM user")
    rows = cur.fetchall()
    for each_user in rows:
        user_id = each_user[0]
        user_title = each_user[1]
        user_table[user_id] = user_title

conn = create_connection(database)
with conn:
    cur = conn.cursor()
    
    drop_table_message = 'DROP TABLE augmentedThreads;'
    cur.execute(drop_table_message)

    new_table_message = 'CREATE TABLE augmentedThreads (id TEXT PRIMARY KEY, inst_replied INT NOT NULL, intervention_time INT, intervention_message TEXT);'
    cur.execute(new_table_message)
    
    thread_message = 'SELECT id, starter FROM thread '
    thread_message += limit_message
    thread_message += ' ORDER BY posted_time'
    print(thread_message)
    cur.execute(thread_message)
    threads = cur.fetchall()
    for each_thread in threads:
        # print("heheda")
        
        # All the info from this select operation
        thread_id = each_thread[0]
        thread_starter = each_thread[1]
        
        # Initialize intervention time as -1
        if(thread_starter in user_table and (user_table[thread_starter] == 'Instructor' or user_table[thread_starter] == 'Staff')):           
            continue

        # Detect the earliest intervention.            
        message_select = 'SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = \'%s\' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = \'%s\') ORDER BY post_time;' % (thread_id, thread_id);
        cur.execute(message_select)
        # print(message_select)
        all_messages = cur.fetchall()

        intervened = False
        for each_message in all_messages:
            post_id = each_message[0]
            poster = each_message[1]
            post_text = each_message[2]
            post_time = each_message[3]

            if is_gratitude(post_text) or (poster in user_table and (user_table[poster] == 'Instructor' or user_table[poster] == 'Staff')):
                message_insert = 'INSERT INTO augmentedThreads VALUES(\'%s\', 1, %s, \'%s\')' % (thread_id, post_time, post_id)
                intervened = True
                break

        if not intervened:
            message_insert = 'INSERT INTO augmentedThreads (id, inst_replied) VALUES(\'%s\', 0)' % thread_id
            
        cur.execute(message_insert)
# Out:
# please input the database name: courseraData.db
# please input the limit message: WHERE forumid = 'ZMQXwSj1Eea7jBLLHPwd0w'
# SELECT id, starter FROM thread WHERE forumid = 'ZMQXwSj1Eea7jBLLHPwd0w' ORDER BY posted_time
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~2JYEX5F1Eea8RAoAZIJsnw' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~2JYEX5F1Eea8RAoAZIJsnw') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GXuO-J9AEeaprQ4LnRHZcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GXuO-J9AEeaprQ4LnRHZcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Jk9IgZ98Eea63Q75EgCRcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Jk9IgZ98Eea63Q75EgCRcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~eRodhJ-FEeazNRJWtRtwXA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~eRodhJ-FEeazNRJWtRtwXA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~fQIkm5-TEea63Q75EgCRcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~fQIkm5-TEea63Q75EgCRcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GOr81J-8EeapjQ4Z0Pl1JA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GOr81J-8EeapjQ4Z0Pl1JA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Zludd6AbEeaprQ4LnRHZcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Zludd6AbEeaprQ4LnRHZcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~YGaeaKApEeaEcApNwLcIRA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~YGaeaKApEeaEcApNwLcIRA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~hpTvVqA_EeaWGQ4arwmx_A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~hpTvVqA_EeaWGQ4arwmx_A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Q-EnX6BHEea8DBIggA9NJg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Q-EnX6BHEea8DBIggA9NJg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~rfEamaBhEeadhwrR3lohrA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~rfEamaBhEeadhwrR3lohrA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~QeJ-oqBxEeadhwrR3lohrA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~QeJ-oqBxEeadhwrR3lohrA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZGgYwqEuEea8DBIggA9NJg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZGgYwqEuEea8DBIggA9NJg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~356vx6E7EeaWGQ4arwmx_A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~356vx6E7EeaWGQ4arwmx_A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~dVMZmqFOEea63Q75EgCRcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~dVMZmqFOEea63Q75EgCRcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~fpYr56FdEeaEcApNwLcIRA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~fpYr56FdEeaEcApNwLcIRA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~w48kiKGBEeaeFgp1HJGIrg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~w48kiKGBEeaeFgp1HJGIrg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Z2Z0mqG8EeaMbxJjq5r6sA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Z2Z0mqG8EeaMbxJjq5r6sA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~4Ru3qqHIEeagbRJODex4yg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~4Ru3qqHIEeagbRJODex4yg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UtVDYKH7Eea63Q75EgCRcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UtVDYKH7Eea63Q75EgCRcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~3sBqRqIPEeaWGQ4arwmx_A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~3sBqRqIPEeaWGQ4arwmx_A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZKmgIqJFEea63Q75EgCRcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZKmgIqJFEea63Q75EgCRcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~6DzwCqJbEeaprQ4LnRHZcg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~6DzwCqJbEeaprQ4LnRHZcg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~s8hoq6JeEeaURQ7PXsSdbA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~s8hoq6JeEeaURQ7PXsSdbA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~X_pT_aK1EeaJsxK88fW92A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~X_pT_aK1EeaJsxK88fW92A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~TT7kZ6MFEea8DBIggA9NJg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~TT7kZ6MFEea8DBIggA9NJg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~WhIZEaMtEeaEcApNwLcIRA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~WhIZEaMtEeaEcApNwLcIRA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~SuIvUaNaEeaeFgp1HJGIrg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~SuIvUaNaEeaeFgp1HJGIrg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~x9sof6NiEeazNRJWtRtwXA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~x9sof6NiEeazNRJWtRtwXA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~-WEH5KNsEeadhwrR3lohrA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~-WEH5KNsEeadhwrR3lohrA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~EkDHMaONEeagbRJODex4yg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~EkDHMaONEeagbRJODex4yg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~r7KfBqPREeaeFgp1HJGIrg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~r7KfBqPREeaeFgp1HJGIrg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~_xWAVKPrEeazNRJWtRtwXA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~_xWAVKPrEeazNRJWtRtwXA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~RQmhbqQbEea8DBIggA9NJg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~RQmhbqQbEea8DBIggA9NJg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~drLgSKQoEeaLHgodcuF5pg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~drLgSKQoEeaLHgodcuF5pg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~kVccHKQsEeaLHgodcuF5pg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~kVccHKQsEeaLHgodcuF5pg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Us683qQuEeaWGQ4arwmx_A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~Us683qQuEeaWGQ4arwmx_A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~C9vd_KQxEeaeFgp1HJGIrg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~C9vd_KQxEeaeFgp1HJGIrg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GUN4h6RbEeaLHgodcuF5pg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~GUN4h6RbEeaLHgodcuF5pg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~EzxAm6SFEeaEcApNwLcIRA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~EzxAm6SFEeaEcApNwLcIRA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~l9V_g6ShEeaEcApNwLcIRA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~l9V_g6ShEeaEcApNwLcIRA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UbCIk6StEeaURQ7PXsSdbA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UbCIk6StEeaURQ7PXsSdbA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~sUk24aS1EeazNRJWtRtwXA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~sUk24aS1EeazNRJWtRtwXA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~YERGtKUHEeaMbxJjq5r6sA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~YERGtKUHEeaMbxJjq5r6sA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ILY9faUREea8DBIggA9NJg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ILY9faUREea8DBIggA9NJg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~lfjd0aVFEeagbRJODex4yg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~lfjd0aVFEeagbRJODex4yg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~mvWJ76VIEeaeFgp1HJGIrg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~mvWJ76VIEeaeFgp1HJGIrg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~qDnc8qVbEeaMbxJjq5r6sA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~qDnc8qVbEeaMbxJjq5r6sA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UVL0SaXqEeaCbg44JUM1Vg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~UVL0SaXqEeaCbg44JUM1Vg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~_YrihqaeEeapjQ4Z0Pl1JA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~_YrihqaeEeapjQ4Z0Pl1JA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZiZaS6bLEeadhwrR3lohrA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~ZiZaS6bLEeadhwrR3lohrA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~PIf5iKcTEeagbRJODex4yg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~PIf5iKcTEeagbRJODex4yg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~sY7A1qd6EeapjQ4Z0Pl1JA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~sY7A1qd6EeapjQ4Z0Pl1JA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~9I1-BKpeEeayngpifDPfYA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~9I1-BKpeEeayngpifDPfYA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~WxnKNqroEeaBBQp4inlmBg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~WxnKNqroEeaBBQp4inlmBg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~OBcr7KtDEeayfRIMfs2y9A' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~OBcr7KtDEeayfRIMfs2y9A') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~NVT_rKuNEea9Wg4alTWasA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~NVT_rKuNEea9Wg4alTWasA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~teYyIquuEea79QpTvvAdBA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~teYyIquuEea79QpTvvAdBA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~cOY6VKz1EeamngrNZbefFg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~cOY6VKz1EeamngrNZbefFg') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~XwEryLuHEeaGMhL6_lg_XA' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~XwEryLuHEeaGMhL6_lg_XA') ORDER BY post_time;
# SELECT * FROM (SELECT id, user, post_text, post_time FROM post WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~1947n70UEeaVegrLvStXDg' UNION SELECT id, user, comment_text, post_time FROM comment WHERE thread_id = 'yQcuJCOcEeagwg7hVay0BQ~1947n70UEeaVegrLvStXDg') ORDER BY post_time;
